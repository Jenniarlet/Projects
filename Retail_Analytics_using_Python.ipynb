# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenniarlet/Projects/blob/main/Retail_Analytics_using_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [link text](https:// [link text](https:// [link text](https:// [link text](https://))))<p style="font-family: Arial; font-size:2.5em;color:green;">  </p>
# <p style="font-family: Arial; font-size:2.5em;color:orange;"> Retail Analytics Using Python </p>

# %% [markdown]
# ## Data: Superstore Data

# %% [markdown]
# ##### Import Libraries

# %%
# !pip install squarify
# Out:
# Collecting squarify
#   Downloading squarify-0.4.3-py3-none-any.whl (4.3 kB)
# Installing collected packages: squarify
# Successfully installed squarify-0.4.3

# %%
# Import Libarires
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import seaborn as sns
import squarify

# %% [markdown]
# ###### Import Data

# %%
data= pd.read_excel('/superstore.xls')
data.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# 0       42420   South  FUR-BO-10001798        Furniture    Bookcases
# 1       42420   South  FUR-CH-10000454        Furniture       Chairs
# 2       90036    West  OFF-LA-10000240  Office Supplies       Labels
# 3       33311   South  FUR-TA-10000577        Furniture       Tables
# 4       33311   South  OFF-ST-10000760  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# 3      Bretford CR4500 Series Slim Rectangular Table  957.5775         5
# 4                     Eldon Fold 'N Roll Cart System   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164
#
# [5 rows x 21 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##### Shape of the Data

# %%
data.shape
# Out:
# (9994, 21)

# %%
print("Number of attrtibutes or variables",data.shape[1])
print("Number of customers",data.shape[0])
# Out:
# Number of attrtibutes or variables 21
# Number of customers 9994

# %%
data.sample(5)
#provides random samples
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 3443    3444  CA-2017-168858 2017-11-19 2017-11-23  Standard Class
# 5782    5783  CA-2015-155586 2015-12-12 2015-12-16    Second Class
# 717      718  CA-2017-108910 2017-09-24 2017-09-29  Standard Class
# 4365    4366  CA-2017-111332 2017-05-20 2017-05-22    Second Class
# 5389    5390  CA-2017-164707 2017-02-18 2017-02-21    Second Class
#
#      Customer ID     Customer Name    Segment        Country           City  \
# 3443    JD-16150  Justin Deggeller  Corporate  United States  New York City
# 5782    XP-21865      Xylona Preis   Consumer  United States          Chico
# 717     KC-16540   Kelly Collister   Consumer  United States         Newark
# 4365    NC-18340       Nat Carroll   Consumer  United States          Fargo
# 5389    CV-12805     Cynthia Voltz  Corporate  United States    Los Angeles
#
#       ... Postal Code   Region       Product ID         Category Sub-Category  \
# 3443  ...       10011     East  OFF-AP-10003849  Office Supplies   Appliances
# 5782  ...       95928     West  OFF-EN-10003072  Office Supplies    Envelopes
# 717   ...       43055     East  FUR-FU-10002253        Furniture  Furnishings
# 4365  ...       58103  Central  OFF-FA-10001843  Office Supplies    Fasteners
# 5389  ...       90045     West  OFF-LA-10004345  Office Supplies       Labels
#
#                                            Product Name     Sales  Quantity  \
# 3443     Hoover Shoulder Vac Commercial Portable Vacuum  2504.740         7
# 5782                              Peel & Seel Envelopes    15.520         4
# 717   Howard Miller 13" Diameter Pewter Finish Round...   103.056         3
# 4365                                            Staples     7.410         3
# 5389                                          Avery 493     9.820         2
#
#       Discount    Profit
# 3443       0.0  626.1850
# 5782       0.0    7.4496
# 717        0.2   24.4758
# 4365       0.0    3.4827
# 5389       0.0    4.8118
#
# [5 rows x 21 columns]

# %% [markdown]
# ## List of Variables

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %% [markdown]
# ### Descriptive  Statistics

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
data.describe(percentiles= .1,.2,.3,.4,.5)
# Out:
#   File "<ipython-input-18-b55d72ca47fe>", line 1
#     data.describe(percentiles= .1,.2,.3,.4,.5)
#                                              ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ### Data Types

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
#  17  Sales          9994 non-null   float64
#  18  Quantity       9994 non-null   int64
#  19  Discount       9994 non-null   float64
#  20  Profit         9994 non-null   float64
# dtypes: datetime64[ns](2), float64(3), int64(3), object(13)
# memory usage: 1.6+ MB

# %% [markdown]
# ###  Missing Values In Percentage

# %%
m=pd.DataFrame(((data.isnull().sum())/len(data))*100).reset_index()
m.columns=['Attributes','Percentage of Missing']
m
# Out:
#        Attributes  Percentage of Missing
# 0          Row ID                    0.0
# 1        Order ID                    0.0
# 2      Order Date                    0.0
# 3       Ship Date                    0.0
# 4       Ship Mode                    0.0
# 5     Customer ID                    0.0
# 6   Customer Name                    0.0
# 7         Segment                    0.0
# 8         Country                    0.0
# 9            City                    0.0
# 10          State                    0.0
# 11    Postal Code                    0.0
# 12         Region                    0.0
# 13     Product ID                    0.0
# 14       Category                    0.0
# 15   Sub-Category                    0.0
# 16   Product Name                    0.0
# 17          Sales                    0.0
# 18       Quantity                    0.0
# 19       Discount                    0.0
# 20         Profit                    0.0

# %%
#we have a good amount of non missing data

# %% [markdown]
# ## Exttracting Month and Year from Ship Date

# %%
data['Month']= pd.DatetimeIndex(data['Ship Date']).month
data['Year']= pd.DatetimeIndex(data['Ship Date']).year

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Month',
#        'Year'],
#       dtype='object')

# %%
 data['Order Date'].dt.day_name()
# Out:
# 0        Tuesday
# 1        Tuesday
# 2         Sunday
# 3         Sunday
# 4         Sunday
#           ...
# 9989     Tuesday
# 9990      Sunday
# 9991      Sunday
# 9992      Sunday
# 9993    Thursday
# Name: Order Date, Length: 9994, dtype: object

# %% [markdown]
# ### Exploring  Sales

# %% [markdown]
# #### Checking outliers

# %%
dt_sales= data[['Ship Date','Sales']].set_index('Ship Date')
dt_sales.plot()
# Out:
# <Axes: xlabel='Ship Date'>

# %% [markdown]
# ### Removing Outliers

# %%
# outliers = data[data['SalesAmount'] > (data['SalesAmount'].mean() + (3 * data['SalesAmount'].std()))]
# outliers2 = data[data['SalesAmount'] < (data['SalesAmount'].mean() - (3 * data['SalesAmount'].std()))]

#removing outliers from data:
print(data['Sales'].mean(), data['Sales'].std(), data['Sales'].mean() - 3 * data['Sales'].std(), data['Sales'].mean() + 3 * data['Sales'].std())
data = data[data['Sales'] < (data['Sales'].mean() + (3 * data['Sales'].std()))]
data = data[data['Sales'] > (data['Sales'].mean() - (3 * data['Sales'].std()))]
# Out:
# 229.85800083049833 623.2451005086808 -1639.877300695544 2099.593302356541

# %%
dt_sales2= data[['Ship Date','Sales']].set_index('Ship Date')

dt_sales2.plot()
# Out:
# <Axes: xlabel='Ship Date'>

# %% [markdown]
# ### Year and Month  Wise Sales

# %%
data.groupby(data.Year).sum()['Sales']
# Out:
# <ipython-input-28-21843fdfeafa>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(data.Year).sum()['Sales']
# Year
# 2014    350375.6581
# 2015    397297.2200
# 2016    460097.2204
# 2017    568638.2654
# 2018      5159.6968
# Name: Sales, dtype: float64

# %%
data.groupby(data.Year).sum()['Sales'].plot(kind='bar')
# Out:
# <ipython-input-29-16c17177fde8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(data.Year).sum()['Sales'].plot(kind='bar')
# <Axes: xlabel='Year'>

# %%
data.groupby(data.Month).sum()['Sales']
# Out:
# <ipython-input-30-5f89dfab3659>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(data.Month).sum()['Sales']
# Month
# 1      78624.8734
# 2      57254.5424
# 3     114969.3120
# 4     108057.2678
# 5     109594.6879
# 6     134625.2497
# 7     125470.5570
# 8     129784.6595
# 9     237056.4583
# 10    141400.5110
# 11    256698.4765
# 12    288031.4652
# Name: Sales, dtype: float64

# %%
data.groupby(data.Month).sum()['Sales'].plot(kind='bar')
# Out:
# <ipython-input-31-7cad13d9aa74>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   data.groupby(data.Month).sum()['Sales'].plot(kind='bar')
# <Axes: xlabel='Month'>

# %% [markdown]
# ### Product Category wise Sales in Percentage

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit', 'Month',
#        'Year'],
#       dtype='object')

# %%
dk = data.groupby(['Category']).agg({'Sales':np.sum}).reset_index()
fig1 = plt.figure(figsize =(10, 7))
plt.pie(dk.Sales, labels = dk.Category,autopct='%1.3f%%')
# show plot
plt.show()

# %%
# Category
di=dk.sort_values('Sales')
fig2 = plt.figure(figsize = (10, 5))
plt.bar(di.Category, di.Sales, color ='green', width = 0.4)
plt.xlabel("Categories")
plt.ylabel("Total Sales")
# show plot
plt.show()

# %% [markdown]
# ### Week Day Wise Sales

# %%
dj = data.groupby(['Order Date', 'Order ID']).size()
new_df = dj.to_frame(name = 'size').reset_index()
new_df['NumberofOrders']=1
new_df['day_of_week'] = new_df['Order Date'].dt.day_name()

dataSales = new_df.groupby('day_of_week')['NumberofOrders'].agg('sum').reset_index()
dataSales = dataSales.loc[[1,5,6,4,0,2,3], :]

# #plotting bar chart
fig = plt.figure(figsize = (15, 5))
plt.bar(dataSales.day_of_week, dataSales.NumberofOrders, color ='maroon', width = 0.6)
plt.xlabel("Day of week")
plt.ylabel("Total orders")
plt.show()

# %%
new_df
# Out:
#      Order Date        Order ID  size  NumberofOrders day_of_week
# 0    2014-01-03  CA-2014-103800     1               1      Friday
# 1    2014-01-04  CA-2014-112326     3               1    Saturday
# 2    2014-01-05  CA-2014-141817     1               1      Sunday
# 3    2014-01-06  CA-2014-106054     1               1      Monday
# 4    2014-01-06  CA-2014-130813     1               1      Monday
# ...         ...             ...   ...             ...         ...
# 4979 2017-12-29  US-2017-158526     5               1      Friday
# 4980 2017-12-30  CA-2017-115427     2               1    Saturday
# 4981 2017-12-30  CA-2017-126221     1               1    Saturday
# 4982 2017-12-30  CA-2017-143259     3               1    Saturday
# 4983 2017-12-30  CA-2017-156720     1               1    Saturday
#
# [4984 rows x 5 columns]

# %%
dataSales
# Out:
#   day_of_week  NumberofOrders
# 1      Monday             916
# 5     Tuesday             556
# 6   Wednesday             179
# 4    Thursday             744
# 0      Friday             911
# 2    Saturday             832
# 3      Sunday             846

# %% [markdown]
# ## Count of Sales per Year

# %%
data.groupby('Year')['Order ID'].count()
# Out:
# Year
# 2014    1914
# 2015    2106
# 2016    2544
# 2017    3261
# 2018      42
# Name: Order ID, dtype: int64

# %%
data.groupby('Year')['Order ID'].count().plot(kind= 'bar')
#visualize sales
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# # Region wise analysis

# %%
data['Region'].unique()
# Out:
# array(['South', 'West', 'Central', 'East'], dtype=object)

# %%
data.groupby('Region')['Sales'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Region'>

# %% [markdown]
# ## Group by using Year and Category

# %%
data.groupby(['Year','Category'])['Sales'].sum().reset_index()
# Out:
#     Year         Category        Sales
# 0   2014        Furniture  132149.8171
# 1   2014  Office Supplies  111207.5750
# 2   2014       Technology  107018.2660
# 3   2015        Furniture  141475.0510
# 4   2015  Office Supplies  122500.1060
# 5   2015       Technology  133322.0630
# 6   2016        Furniture  175621.4454
# 7   2016  Office Supplies  155274.4160
# 8   2016       Technology  129201.3590
# 9   2017        Furniture  191934.1604
# 10  2017  Office Supplies  203489.6290
# 11  2017       Technology  173214.4760
# 12  2018        Furniture    2864.4068
# 13  2018  Office Supplies    1887.1340
# 14  2018       Technology     408.1560

# %% [markdown]
# ## Pivot Table for Sales across Year and Category

# %%
pd.pivot_table(data, values='Sales',index='Year',columns=['Category'],aggfunc= np.sum).reset_index()
# Out:
# Category  Year    Furniture  Office Supplies  Technology
# 0         2014  132149.8171       111207.575  107018.266
# 1         2015  141475.0510       122500.106  133322.063
# 2         2016  175621.4454       155274.416  129201.359
# 3         2017  191934.1604       203489.629  173214.476
# 4         2018    2864.4068         1887.134     408.156

# %%
table= pd.pivot_table(data, values='Sales',index='Year',columns=['Category'],aggfunc= np.sum).reset_index()

# %%
table.plot.bar(x='Year',y=['Furniture', 'Office Supplies','Technology'],stacked=True)
# Out:
# <Axes: xlabel='Year'>

# %%
table.plot.bar(x='Year',y=['Furniture', 'Office Supplies','Technology'])
# Out:
# <Axes: xlabel='Year'>

# %%
table.plot.bar(x='Year',y=['Furniture', 'Office Supplies','Technology'])
plt.xticks(rotation=0)
plt.xlabel('Year of the Businesss')
plt.ylabel("Sum of the sales amount")
plt.title(" The Sales Details")

plt.show()

# %% [markdown]
# # Month wise analysis

# %%
data.groupby(['Month','Category'])['Sales'].sum().reset_index()
# Out:
#     Month         Category        Sales
# 0       1        Furniture   27253.2804
# 1       1  Office Supplies   30815.7740
# 2       1       Technology   20555.8190
# 3       2        Furniture   16841.9694
# 4       2  Office Supplies   20060.1590
# 5       2       Technology   20352.4140
# 6       3        Furniture   41289.2330
# 7       3  Office Supplies   39830.7690
# 8       3       Technology   33849.3100
# 9       4        Furniture   42637.7158
# 10      4  Office Supplies   35339.5640
# 11      4       Technology   30079.9880
# 12      5        Furniture   38363.0219
# 13      5  Office Supplies   36843.8870
# 14      5       Technology   34387.7790
# 15      6        Furniture   50437.4947
# 16      6  Office Supplies   41985.1660
# 17      6       Technology   42202.5890
# 18      7        Furniture   49161.2900
# 19      7  Office Supplies   34471.2010
# 20      7       Technology   41838.0660
# 21      8        Furniture   35013.0075
# 22      8  Office Supplies   52417.1780
# 23      8       Technology   42354.4740
# 24      9        Furniture   86879.8913
# 25      9  Office Supplies   77859.2870
# 26      9       Technology   72317.2800
# 27     10        Furniture   49444.7130
# 28     10  Office Supplies   45505.9450
# 29     10       Technology   46449.8530
# 30     11        Furniture   90046.9295
# 31     11  Office Supplies   89098.5250
# 32     11       Technology   77553.0220
# 33     12        Furniture  116676.3342
# 34     12  Office Supplies   90131.4050
# 35     12       Technology   81223.7260

# %%
data.groupby('Month')['Sales','Profit'].sum().plot(kind='bar')
# Out:
# <ipython-input-51-afb4e10c2d66>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   data.groupby('Month')['Sales','Profit'].sum().plot(kind='bar')
# <Axes: xlabel='Month'>

# %% [markdown]
# ## Month and Region Wise Exploration

# %%
data.groupby([pd.Grouper(key='Ship Date', freq='M'), 'Region'])\
    .agg(unique_items=('Product ID', 'nunique'),
         total_Sales=('Sales','sum'),
         total_Profit=('Profit','sum')).head(20)
# Out:
#                     unique_items  total_Sales  total_Profit
# Ship Date  Region
# 2014-01-31 Central            19     1299.406      106.8400
#            East                9      432.246      -40.6821
#            South              31     6748.272     1600.2562
#            West               12     2221.387       11.2906
# 2014-02-28 Central            21     1473.674      306.4569
#            East                3      184.248       60.6745
#            South               8     2028.986      279.3395
#            West               18     1719.620      219.7216
# 2014-03-31 Central            21     2813.537     -429.8596
#            East               31     5215.820     -748.5753
#            South              47     6770.842      950.1297
#            West               39     9769.740     1252.8140
# 2014-04-30 Central            30     6726.405      385.1916
#            East               21     2865.974     -455.1220
#            South              29     6242.287     1398.9921
#            West               50    10389.749     1900.9141
# 2014-05-31 Central            31     2973.075     -456.1760
#            East               40     7350.197      666.0500
#            South              24     4056.134      470.1232
#            West               29     5383.544      679.7328

# %%
data.resample('M',on='Ship Date').Sales.sum().head(10)
# Out:
# Ship Date
# 2014-01-31    10701.3110
# 2014-02-28     5406.5280
# 2014-03-31    24569.9390
# 2014-04-30    26224.4150
# 2014-05-31    19762.9500
# 2014-06-30    32725.2796
# 2014-07-31    22625.3600
# 2014-08-31    30245.2420
# 2014-09-30    40726.5743
# 2014-10-31    30656.7050
# Freq: M, Name: Sales, dtype: float64

# %%
data_M= data.resample('M',on='Order Date').Sales.sum()

# %%
data_M= pd.DataFrame(data_M).reset_index()
data_M.head()
# Out:
#   Order Date      Sales
# 0 2014-01-31  11663.075
# 1 2014-02-28   4519.892
# 2 2014-03-31  29552.599
# 3 2014-04-30  24131.295
# 4 2014-05-31  20932.357

# %% [markdown]
# ## Filtering

# %%
dl= data.set_index('Order Date')
dl.loc['2016':'2017']
# Out:
# <ipython-input-58-4f5b17786a2b>:2: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   dl.loc['2016':'2017']
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-08       1  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-11-08       2  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-06-12       3  CA-2016-138688 2016-06-16    Second Class    DV-13045
# 2017-04-15      13  CA-2017-114412 2017-04-20  Standard Class    AA-10480
# 2016-12-05      14  CA-2016-161389 2016-12-10  Standard Class    IM-15070
# ...            ...             ...        ...             ...         ...
# 2017-11-17    9989  CA-2017-163629 2017-11-21  Standard Class    RA-19885
# 2017-02-26    9991  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9992  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-02-26    9993  CA-2017-121258 2017-03-03  Standard Class    DB-13060
# 2017-05-04    9994  CA-2017-119914 2017-05-09    Second Class    CC-12220
#
#               Customer Name    Segment        Country         City  \
# Order Date
# 2016-11-08      Claire Gute   Consumer  United States    Henderson
# 2016-11-08      Claire Gute   Consumer  United States    Henderson
# 2016-06-12  Darrin Van Huff  Corporate  United States  Los Angeles
# 2017-04-15     Andrew Allen   Consumer  United States      Concord
# 2016-12-05     Irene Maddox   Consumer  United States      Seattle
# ...                     ...        ...            ...          ...
# 2017-11-17     Ruben Ausman  Corporate  United States       Athens
# 2017-02-26      Dave Brooks   Consumer  United States   Costa Mesa
# 2017-02-26      Dave Brooks   Consumer  United States   Costa Mesa
# 2017-02-26      Dave Brooks   Consumer  United States   Costa Mesa
# 2017-05-04     Chris Cortes   Consumer  United States  Westminster
#
#                      State  ...       Product ID         Category  \
# Order Date                  ...
# 2016-11-08        Kentucky  ...  FUR-BO-10001798        Furniture
# 2016-11-08        Kentucky  ...  FUR-CH-10000454        Furniture
# 2016-06-12      California  ...  OFF-LA-10000240  Office Supplies
# 2017-04-15  North Carolina  ...  OFF-PA-10002365  Office Supplies
# 2016-12-05      Washington  ...  OFF-BI-10003656  Office Supplies
# ...                    ...  ...              ...              ...
# 2017-11-17         Georgia  ...  TEC-PH-10004006       Technology
# 2017-02-26      California  ...  FUR-FU-10000747        Furniture
# 2017-02-26      California  ...  TEC-PH-10003645       Technology
# 2017-02-26      California  ...  OFF-PA-10004041  Office Supplies
# 2017-05-04      California  ...  OFF-AP-10002684  Office Supplies
#
#            Sub-Category                                       Product Name  \
# Order Date
# 2016-11-08    Bookcases                  Bush Somerset Collection Bookcase
# 2016-11-08       Chairs  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2016-06-12       Labels  Self-Adhesive Address Labels for Typewriters b...
# 2017-04-15        Paper                                         Xerox 1967
# 2016-12-05      Binders        Fellowes PB200 Plastic Comb Binding Machine
# ...                 ...                                                ...
# 2017-11-17       Phones                    Panasonic KX - TS880B Telephone
# 2017-02-26  Furnishings  Tenex B1-RE Series Chair Mats for Low Pile Car...
# 2017-02-26       Phones                              Aastra 57i VoIP phone
# 2017-02-26        Paper  It's Hot Message Books with Stickers, 2 3/4" x 5"
# 2017-05-04   Appliances  Acco 7-Outlet Masterpiece Power Center, Wihtou...
#
#               Sales Quantity  Discount    Profit  Month  Year
# Order Date
# 2016-11-08  261.960        2       0.0   41.9136     11  2016
# 2016-11-08  731.940        3       0.0  219.5820     11  2016
# 2016-06-12   14.620        2       0.0    6.8714      6  2016
# 2017-04-15   15.552        3       0.2    5.4432      4  2017
# 2016-12-05  407.976        3       0.2  132.5922     12  2016
# ...             ...      ...       ...       ...    ...   ...
# 2017-11-17  206.100        5       0.0   55.6470     11  2017
# 2017-02-26   91.960        2       0.0   15.6332      3  2017
# 2017-02-26  258.576        2       0.2   19.3932      3  2017
# 2017-02-26   29.600        4       0.0   13.3200      3  2017
# 2017-05-04  243.160        2       0.0   72.9480      5  2017
#
# [5824 rows x 22 columns]

# %%
data.loc[data['Region']== 'South',['Region','Sales'] ]
# Out:
#      Region     Sales
# 0     South  261.9600
# 1     South  731.9400
# 3     South  957.5775
# 4     South   22.3680
# 12    South   15.5520
# ...     ...       ...
# 9971  South  140.7500
# 9980  South   85.9800
# 9987  South   79.9900
# 9988  South  206.1000
# 9989  South   25.2480
#
# [1596 rows x 2 columns]

# %% [markdown]
# ###  Interactive Graph  with Slide Bar using Plotly

# %%
import plotly.express as px
fig = px.line(data_M, x = 'Order Date',y='Sales',title = 'Monthly Sales')

fig.update_xaxes(rangeslider_visible=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1d787883-8ab5-4bad-ad34-8f7dc6ad80f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d787883-8ab5-4bad-ad34-8f7dc6ad80f3")) {                    Plotly.newPlot(                        "1d787883-8ab5-4bad-ad34-8f7dc6ad80f3",                        [{"hovertemplate":"Order Date=%{x}\u003cbr\u003eSales=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":["2014-01-31T00:00:00","2014-02-28T00:00:00","2014-03-31T00:00:00","2014-04-30T00:00:00","2014-05-31T00:00:00","2014-06-30T00:00:00","2014-07-31T00:00:00","2014-08-31T00:00:00","2014-09-30T00:00:00","2014-10-31T00:00:00","2014-11-30T00:00:00","2014-12-31T00:00:00","2015-01-31T00:00:00","2015-02-28T00:00:00","2015-03-31T00:00:00","2015-04-30T00:00:00","2015-05-31T00:00:00","2015-06-30T00:00:00","2015-07-31T00:00:00","2015-08-31T00:00:00","2015-09-30T00:00:00","2015-10-31T00:00:00","2015-11-30T00:00:00","2015-12-31T00:00:00","2016-01-31T00:00:00","2016-02-29T00:00:00","2016-03-31T00:00:00","2016-04-30T00:00:00","2016-05-31T00:00:00","2016-06-30T00:00:00","2016-07-31T00:00:00","2016-08-31T00:00:00","2016-09-30T00:00:00","2016-10-31T00:00:00","2016-11-30T00:00:00","2016-12-31T00:00:00","2017-01-31T00:00:00","2017-02-28T00:00:00","2017-03-31T00:00:00","2017-04-30T00:00:00","2017-05-31T00:00:00","2017-06-30T00:00:00","2017-07-31T00:00:00","2017-08-31T00:00:00","2017-09-30T00:00:00","2017-10-31T00:00:00","2017-11-30T00:00:00","2017-12-31T00:00:00"],"xaxis":"x","y":[11663.075,4519.892,29552.599000000002,24131.295000000002,20932.357,31328.7516,23581.159,27909.4685,47028.4518,28717.441,60992.9807,53882.4925,11072.5116,9409.431,25827.692,30382.2385,21790.5825,21746.916,26455.675,31018.3722,57283.784,28951.4935,59355.5215,62544.4492,18542.491,14228.865,30456.771,29650.109,36411.002,32843.806,34031.923,28228.3183,60511.2613,32251.909,63506.4168,79862.753,25363.502,20301.1334,39472.4828,23889.0371,38097.2382,44932.0897,40469.256,44719.448000000004,75702.891,49424.419200000004,90122.901,78469.4068],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953 ...

# %% [markdown]
# # RFM Analysis

# %% [markdown]
# #### RFM stands for Recency, Frequency, and Monetary value, each corresponding to some key customer trait. These RFM metrics are important indicators of a customer’s behavior because frequency and monetary value affects a customer’s lifetime value, and recency affects retention, a measure of engagement.

# %% [markdown]
# #### Recency: The number of days between present date (i.e. Today) and date of last purchase of each customer. First define today's date and then get the `.max()` function of `InvoiceDate` to calculate the number of days between today and date of last purchase.
#
# ####  Frequency: How often has a customer transacted or interacted with the brand during a particular period of time? Clearly, customers with frequent activities are more engaged, and probably more loyal, than customers who rarely do so. And one-time-only customers are in a class of their own.
#
# ####  Monetary: Also referred to as “monetary value,” this factor reflects how much a customer has spent with the brand during a particular period of time. Big spenders should usually be treated differently than customers who spend little. Looking at monetary divided by frequency indicates the average purchase amount – an important secondary factor to consider when segmenting customers.

# %% [markdown]
# ###  RFM factors illustrate these facts:
# ##### the more recent the purchase, the more responsive the customer is to promotions
# ##### the more frequently the customer buys, the more engaged and satisfied they are
# ##### monetary value differentiates heavy spenders from low-value purchasers

# %% [markdown]
# ### The maximum and minimum date

# %%
data['Order Date'].max(), data['Order Date'].min()
# Out:
# (Timestamp('2017-12-30 00:00:00'), Timestamp('2014-01-03 00:00:00'))

# %%
TODAY = dt.datetime(2017,12,31)

# %%
rfm = data.groupby("Customer ID").agg({"Order Date": lambda date: (TODAY - date.max()).days,
                                        "Order ID": lambda num: num.nunique(),
                                        "Sales": lambda price: price.sum()})

# %%
# Change the name of columns
rfm.columns=["recency", "frequency", "monetary"]

# %%
rfm# use this data to send coupons etc
# Out:
#              recency  frequency  monetary
# Customer ID
# AA-10315         185          5  1633.488
# AA-10375          20          9  1056.390
# AA-10480         260          4  1790.512
# AA-10645          56          6  5086.935
# AB-10015         416          3   886.156
# ...              ...        ...       ...
# XP-21865          44         11  2374.658
# YC-21895           5          5  2520.020
# YS-21880          10          8  3926.916
# ZC-21910          55         13  8025.707
# ZD-21925         203          5  1493.944
#
# [793 rows x 3 columns]

# %%
print("Recency: {} to {}".format(rfm.recency.min(), rfm.recency.max()))
print("Frequency: {} to {}".format(rfm.frequency.min(), rfm.frequency.max()))
print("Monetary: {} to {}".format(rfm.monetary.min(), rfm.monetary.max()))

#recency is the range
# Out:
# Recency: 1 to 1166
# Frequency: 1 to 17
# Monetary: 4.833000000000001 to 8331.986

# %% [markdown]
# # Customer Life Time Value

# %% [markdown]
# ####  Customer Lifetime Value is a monetary value that represents the amount of revenue or profit a customer will give the company over the period of the relationship" (Source). CLTV demonstrates the implications of acquiring long-term customers compare to short-term customers. Customer lifetime value (CLV) can help you to answers the most important questions about sales to every company:

# %% [markdown]
#     How to Identify the most profitable customers?
#     How can a company offer the best product and make the most money?
#     How to segment profitable customers?
#     How much budget need to spend to acquire customers?

# %% [markdown]
# # Aggregate Model

# %% [markdown]
# The most simplest and the oldest method of computing CLV is this Aggregate/Average method. This assumes a constant average spend and churn rate for all the customers.
#
# This method does not differentiate between customers and produces a single value for CLV at an overall Level. This leads to unrealistic estimates if some of the customers transacted in high value and high volume, which ultimately skews the average CLV value.
#
# The General Formula for calculating CLV is:

# %% [markdown]
# ### CLV = ((Average Sales X Purchase Frequency) / Churn) X Profit Margin

# %% [markdown]
# **Where,**
#   **Average Sales = TotalSales/Total no. of orders**
#
#    **Purchase Frequency = Total no. of orders/Total unique customers**
#
#    **Retention rate = Total no. of orders greater than 1/ Total unique customers**
#
#    **Churn = 1 - Retention rate**
#
#    **Profit Margin = Based on business context**

# %% [markdown]
# In this example case,  the Profit margin for each transaction is assumed to be 5%.

# %% [markdown]
# ### Slicing Data for CLV Analaysis

# %%
data_clv= data[['Customer ID','Order ID', 'Order Date', 'Sales']]
data_clv.head(2)
# Out:
#   Customer ID        Order ID Order Date   Sales
# 0    CG-12520  CA-2016-152156 2016-11-08  261.96
# 1    CG-12520  CA-2016-152156 2016-11-08  731.94

# %%
customer = data_clv.groupby('Customer ID').agg({'Order Date':lambda x: (x.max() - x.min()).days,
                                                   'Order ID': lambda x: len(x),
                                                  'Sales': lambda x: sum(x)})

customer.columns = ['Days', 'Frequency', 'TotalSales']
customer.head()
# Out:
#              Days  Frequency  TotalSales
# Customer ID
# AA-10315     1186         10    1633.488
# AA-10375     1330         15    1056.390
# AA-10480     1077         12    1790.512
# AA-10645     1232         18    5086.935
# AB-10015      996          6     886.156

# %%
customer.shape
# Out:
# (793, 3)

# %%
data_clv['Order Date'].max()
# Out:
# Timestamp('2017-12-30 00:00:00')

# %%
data_clv['Order Date'].min()
# Out:
# Timestamp('2014-01-03 00:00:00')

# %%
# Calculating the necessary variables for CLV calculation
Average_sales = round(np.mean(customer['TotalSales']),2)
print(f"Average sales: ${Average_sales}")

Purchase_freq = round(np.mean(customer['Frequency']), 2)
print(f"Purchase Frequency: {Purchase_freq}")

Retention_rate = customer[customer['Frequency']>1].shape[0]/customer.shape[0]
churn = round(1 - Retention_rate, 2)
print(f"Churn: {churn}%")
# Out:
# Average sales: $2246.62
# Purchase Frequency: 12.44
# Churn: 0.01%

# %%
customer['TotalSales'].mean()
# Out:
# 2246.6179832282473

# %%
# Calculating the CLV
Profit_margin = 0.05

CLV = round(((Average_sales * Purchase_freq/churn)) * Profit_margin, 2)
print(f"The Customer Lifetime Value (CLV) for each customer is: ${CLV}")
# Out:
# The Customer Lifetime Value (CLV) for each customer is: $139739.76

# %% [markdown]
# #   Conversion Rate

# %%
data.groupby('Year')['Order ID'].count()
# Out:
# Year
# 2014    1914
# 2015    2106
# 2016    2544
# 2017    3261
# 2018      42
# Name: Order ID, dtype: int64

# %%
dt= pd.DataFrame(data.groupby('Year')['Order ID'].count()).reset_index()
dt.columns=['Year', 'No. of Transactions']
dt
# Out:
#    Year  No. of Transactions
# 0  2014                 1914
# 1  2015                 2106
# 2  2016                 2544
# 3  2017                 3261
# 4  2018                   42

# %%
dt['Footfall']= [10000,15000,20000,25000,30000]
# we are inserting this. football = how many ppl visited the store but they didn't buy anything
#they turn to customers if they purchase

# %%
dt

# %%
dt['Conversion Rate']= dt['No. of Transactions']/dt['Footfall']*100
dt
# Out:
#    Year  No. of Transactions  Footfall  Conversion Rate
# 0  2014                 1914     10000           19.140
# 1  2015                 2106     15000           14.040
# 2  2016                 2544     20000           12.720
# 3  2017                 3261     25000           13.044
# 4  2018                   42     30000            0.140
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dt['Year'].plot(kind='hist', bins=20, title='Year')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt['No. of Transactions'].plot(kind='hist', bins=20, title='No. of Transactions')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt['Footfall'].plot(kind='hist', bins=20, title='Footfall')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt['Conversion Rate'].plot(kind='hist', bins=20, title='Conversion Rate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dt.plot(kind='scatter', x='Year', y='No. of Transactions', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt.plot(kind='scatter', x='No. of Transactions', y='Footfall', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# dt.plot(kind='scatter', x='Footfall', y='Conversion Rate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['No. of Transactions']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = dt.sort_values('Year', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('No. of Transactions')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Year']
#   ys = series['Conversion Rate']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = dt.sort_values('Year', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('Conversion Rate')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['Year']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'Year'}, axis=1)
#               .sort_values('Year', ascending=True))
#   xs = counted['Year']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = dt.sort_values('Year', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Year')
# _ = plt.ylabel('count()')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['Footfall']
#   ys = series['No. of Transactions']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = dt.sort_values('Footfall', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('Footfall')
# _ = plt.ylabel('No. of Transactions')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# dt['Year'].plot(kind='line', figsize=(8, 4), title='Year')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dt['No. of Transactions'].plot(kind='line', figsize=(8, 4), title='No. of Transactions')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dt['Footfall'].plot(kind='line', figsize=(8, 4), title='Footfall')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# dt['Conversion Rate'].plot(kind='line', figsize=(8, 4), title='Conversion Rate')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# # Market Basket Analysis

# %% [markdown]
# # Frequency of Most Popular Item

# %%
# looking at the frequency of most popular items

plt.rcParams['figure.figsize'] = (18, 7)
color = plt.cm.copper(np.linspace(0, 1, 20))
data['Product Name'].value_counts().head(10).plot.bar(color = color) # modify head() to limit how many you can see
plt.title('frequency of most popular items', fontsize = 20)
plt.xticks(rotation = 90 )
plt.grid()
plt.show()

# %%
y = data['Product Name'].value_counts().head(50).to_frame()

# %%
# plotting

plt.rcParams['figure.figsize'] = (20, 20)
color = plt.cm.cool(np.linspace(0, 1, 50))
squarify.plot(sizes = y.values, label = y.index, alpha=.8, color = color)
plt.title('Tree Map for Popular Items')
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud

plt.rcParams['figure.figsize'] = (15, 15)
wordcloud = WordCloud(background_color = 'white', width = 1200,  height = 1200, max_words = 121).generate(str(data['Product Name']))
plt.imshow(wordcloud)
plt.axis('off')
plt.title('Most Popular Items',fontsize = 20)
plt.show()

# %%
# recomendation model , if this customer buys this product they will most likely buy this one

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in /usr/local/lib/python3.10/dist-packages (0.22.0)
# Requirement already satisfied: scipy>=1.2.1 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.11.3)
# Requirement already satisfied: numpy>=1.16.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.23.5)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: scikit-learn>=1.0.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.2.2)
# Requirement already satisfied: matplotlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (3.7.1)
# Requirement already satisfied: joblib>=0.13.2 in /usr/local/lib/python3.10/dist-packages (from mlxtend) (1.3.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from mlxtend) (67.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24.2->mlxtend) (2023.3.post1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.2->mlxtend) (3.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %%
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
# for this analysis, data should be customized

# %%
data['Product Name'].value_counts().head(10)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# Staple envelope                               48
# Easy-staple paper                             46
# Staples                                       46
# Avery Non-Stick Binders                       20
# Staples in misc. colors                       19
# KI Adjustable-Height Table                    18
# Staple remover                                18
# Storex Dura Pro Binders                       17
# Staple-based wall hangings                    16
# Situations Contoured Folding Chairs, 4/Set    15
# Name: Product Name, dtype: int64

# %%
df=data.groupby("Product Name").filter(lambda x: len(x) > 14)
df.head()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#      Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 34       35  CA-2017-107727 2017-10-19 2017-10-23    Second Class    MA-17560
# 132     133  US-2017-164147 2017-02-02 2017-02-05     First Class    DW-13585
# 162     163  CA-2016-154508 2016-11-16 2016-11-20  Standard Class    RD-19900
# 239     240  CA-2016-157749 2016-06-04 2016-06-09    Second Class    KL-16645
# 271     272  CA-2015-155334 2015-07-30 2015-07-31     First Class    HA-14920
#
#       Customer Name      Segment        Country           City  ...  \
# 34     Matt Abelman  Home Office  United States        Houston  ...
# 132  Dorothy Wardle    Corporate  United States       Columbus  ...
# 162     Ruben Dartt     Consumer  United States       Carlsbad  ...
# 239    Ken Lonsdale     Consumer  United States        Chicago  ...
# 271  Helen Andreada     Consumer  United States  San Francisco  ...
#
#           Product ID         Category Sub-Category  \
# 34   OFF-PA-10000249  Office Supplies        Paper
# 132  OFF-FA-10002780  Office Supplies    Fasteners
# 162  OFF-EN-10001990  Office Supplies    Envelopes
# 239  FUR-FU-10004351        Furniture  Furnishings
# 271  TEC-AC-10003628       Technology  Accessories
#
#                                           Product Name    Sales Quantity  \
# 34                                   Easy-staple paper   29.472        3
# 132                                            Staples   21.456        9
# 162                                    Staple envelope   28.400        5
# 239                         Staple-based wall hangings   11.688        3
# 271  Logitech 910-002974 M325 Wireless Mouse for We...  209.930        7
#
#     Discount   Profit  Month  Year
# 34       0.2   9.9468     10  2017
# 132      0.2   6.9732      2  2017
# 162      0.0  13.3480     11  2016
# 239      0.6  -4.6752      6  2016
# 271      0.0  92.3692      7  2015
#
# [5 rows x 23 columns]

# %%
df['Product Name'].value_counts()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# Staple envelope                                              48
# Easy-staple paper                                            46
# Staples                                                      46
# Avery Non-Stick Binders                                      20
# Staples in misc. colors                                      19
# Staple remover                                               18
# KI Adjustable-Height Table                                   18
# Storex Dura Pro Binders                                      17
# Staple-based wall hangings                                   16
# Logitech 910-002974 M325 Wireless Mouse for Web Scrolling    15
# Situations Contoured Folding Chairs, 4/Set                   15
# Name: Product Name, dtype: int64

# %%
dt= df.groupby(['Order ID','Product Name'])['Quantity'].sum().unstack().reset_index().fillna(0).set_index('Order ID')
dt
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# Product Name    Avery Non-Stick Binders  Easy-staple paper  \
# Order ID
# CA-2014-101931                      2.0                0.0
# CA-2014-102673                      0.0                0.0
# CA-2014-103366                      0.0                0.0
# CA-2014-103492                      1.0                0.0
# CA-2014-104283                      0.0                0.0
# ...                                 ...                ...
# US-2017-147669                      0.0                0.0
# US-2017-153948                      0.0                4.0
# US-2017-164147                      0.0                0.0
# US-2017-165358                      0.0                0.0
# US-2017-166394                      0.0                0.0
#
# Product Name    KI Adjustable-Height Table  \
# Order ID
# CA-2014-101931                         0.0
# CA-2014-102673                         0.0
# CA-2014-103366                         0.0
# CA-2014-103492                         0.0
# CA-2014-104283                         1.0
# ...                                    ...
# US-2017-147669                         0.0
# US-2017-153948                         0.0
# US-2017-164147                         0.0
# US-2017-165358                         0.0
# US-2017-166394                         0.0
#
# Product Name    Logitech 910-002974 M325 Wireless Mouse for Web Scrolling  \
# Order ID
# CA-2014-101931                                                0.0
# CA-2014-102673                                                0.0
# CA-2014-103366                                                5.0
# CA-2014-103492                                                0.0
# CA-2014-104283                                                0.0
# ...                                                           ...
# US-2017-147669                                                0.0
# US-2017-153948                                                0.0
# US-2017-164147                                                0.0
# US-2017-165358                                                0.0
# US-2017-166394                                                0.0
#
# Product Name    Situations Contoured Folding Chairs, 4/Set  Staple envelope  \
# Order ID
# CA-2014-101931                                         0.0              0.0
# CA-2014-102673                                         0.0              0.0
# CA-2014-103366                                         0.0              0.0
# CA-2014-103492                                         0.0              0.0
# CA-2014-104283                                         0.0              0.0
# ...                                                    ...              ...
# US-2017-147669                                         0.0              0.0
# US-2017-153948                                         0.0              0.0
# US-2017-164147                                         0.0              0.0
# US-2017-165358                                         4.0              0.0
# US-2017-166394                                         0.0              0.0
#
# Product Name    Staple remover  Staple-based wall hangings  Staples  \
# Order ID
# CA-2014-101931             0.0                         0.0      0.0
# CA-2014-102673             0.0                         0.0      5.0
# CA-2014-103366             0.0                         0.0      0.0
# CA-2014-103492             0.0                         0.0      0.0
# CA-2014-104283             0.0                         0.0      0.0
# ...                        ...                         ...      ...
# US-2017-147669             0.0                         0.0     13.0
# US-2017-153948             0.0                         0.0      0.0
# US-2017-164147             0.0                         0.0      9.0
# US-2017-165358             0.0                         0.0      0.0
# US-2017-166394             0.0                         0.0      6.0
#
# Product Name    Staples in misc. colors  Storex Dura Pro Binders
# Order ID
# CA-2014-101931                      0.0                      0.0
# CA-2014-102673                      0.0                      0.0
# CA-2014-103366                      0.0                      0.0
# CA-2014-103492                      0.0                      0.0
# CA-2014-104283                      0.0                      0.0
# ...                                 ...                      ...
# US-2017-147669                      0.0                      0.0
# US-2017-153948                      0.0                      0.0
# US-2017-164147                      0.0                      0.0
# US-2017-165358                      0.0                      0.0
# US-2017-166394                      0.0                      0.0
#
# [269 rows x 11 columns]

# %%
def one_hot_encode(x):
    if x <= 0:
        return 0
    if x >= 1:
        return 1

dt_encode= dt.applymap(one_hot_encode)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
dt_efilter= dt_encode[(dt_encode >0).sum(axis=1)>=2]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.

# %%
dt_efilter
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
# Product Name    Avery Non-Stick Binders  Easy-staple paper  \
# Order ID
# CA-2014-111934                        0                  1
# CA-2014-138317                        0                  0
# CA-2014-160766                        0                  0
# CA-2015-137946                        1                  0
# CA-2016-111213                        1                  0
# CA-2016-116918                        1                  0
# CA-2017-104885                        0                  1
# CA-2017-131807                        0                  0
# CA-2017-148404                        0                  0
#
# Product Name    KI Adjustable-Height Table  \
# Order ID
# CA-2014-111934                           0
# CA-2014-138317                           0
# CA-2014-160766                           1
# CA-2015-137946                           0
# CA-2016-111213                           0
# CA-2016-116918                           0
# CA-2017-104885                           0
# CA-2017-131807                           1
# CA-2017-148404                           1
#
# Product Name    Logitech 910-002974 M325 Wireless Mouse for Web Scrolling  \
# Order ID
# CA-2014-111934                                                  0
# CA-2014-138317                                                  1
# CA-2014-160766                                                  0
# CA-2015-137946                                                  0
# CA-2016-111213                                                  0
# CA-2016-116918                                                  0
# CA-2017-104885                                                  0
# CA-2017-131807                                                  0
# CA-2017-148404                                                  0
#
# Product Name    Situations Contoured Folding Chairs, 4/Set  Staple envelope  \
# Order ID
# CA-2014-111934                                           0                0
# CA-2014-138317                                           0                1
# CA-2014-160766                                           0                1
# CA-2015-137946                                           0                0
# CA-2016-111213                                           0                0
# CA-2016-116918                                           0                0
# CA-2017-104885                                           0                1
# CA-2017-131807                                           0                0
# CA-2017-148404                                           0                0
#
# Product Name    Staple remover  Staple-based wall hangings  Staples  \
# Order ID
# CA-2014-111934               0                           0        0
# CA-2014-138317               0                           0        0
# CA-2014-160766               0                           0        0
# CA-2015-137946               0                           0        0
# CA-2016-111213               1                           0        0
# CA-2016-116918               0                           0        0
# CA-2017-104885               0                           0        0
# CA-2017-131807               0                           0        1
# CA-2017-148404               0                           0        1
#
# Product Name    Staples in misc. colors  Storex Dura Pro Binders
# Order ID
# CA-2014-111934                        0                        1
# CA-2014-138317                        0                        0
# CA-2014-160766                        0                        0
# CA-2015-137946                        0                        1
# CA-2016-111213                        0                        0
# CA-2016-116918                        1                        0
# CA-2017-104885                        0                        0
# CA-2017-131807                        0                        0
# CA-2017-148404                        0                        0

# %%
frequent_itemsets_plus= apriori(dt_efilter, min_support= 0.05,use_colnames= True).sort_values('support', ascending= False).reset_index(drop=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning:
#
# DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type

# %%
rules = association_rules(frequent_itemsets_plus, metric="lift", min_threshold=2)
rules
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning:
#
# `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#                                          antecedents  \
# 0                       (KI Adjustable-Height Table)
# 1                                          (Staples)
# 2                          (Avery Non-Stick Binders)
# 3                                   (Staple remover)
# 4                          (Avery Non-Stick Binders)
# 5                          (Staples in misc. colors)
# 6                          (Storex Dura Pro Binders)
# 7                                (Easy-staple paper)
# 8  (Logitech 910-002974 M325 Wireless Mouse for W...
# 9                                  (Staple envelope)
#
#                                          consequents  antecedent support  \
# 0                                          (Staples)            0.333333
# 1                       (KI Adjustable-Height Table)            0.222222
# 2                                   (Staple remover)            0.333333
# 3                          (Avery Non-Stick Binders)            0.111111
# 4                          (Staples in misc. colors)            0.333333
# 5                          (Avery Non-Stick Binders)            0.111111
# 6                                (Easy-staple paper)            0.222222
# 7                          (Storex Dura Pro Binders)            0.222222
# 8                                  (Staple envelope)            0.111111
# 9  (Logitech 910-002974 M325 Wireless Mouse for W...            0.333333
#
#    consequent support   support  confidence  lift  leverage  conviction  \
# 0            0.222222  0.222222    0.666667  3.00  0.148148    2.333333
# 1            0.333333  0.222222    1.000000  3.00  0.148148         inf
# 2            0.111111  0.111111    0.333333  3.00  0.074074    1.333333
# 3            0.333333  0.111111    1.000000  3.00  0.074074         inf
# 4            0.111111  0.111111    0.333333  3.00  0.074074    1.333333
# 5            0.333333  0.111111    1.000000  3.00  0.074074         inf
# 6            0.222222  0.111111    0.500000  2.25  0.061728    1.555556
# 7            0.222222  0.111111    0.500000  2.25  0.061728    1.555556
# 8            0.333333  0.111111    1.000000  3.00  0.074074         inf
# 9            0.111111  0.111111    0.333333  3.00  0.074074    1.333333
#
#    zhangs_metric
# 0       1.000000
# 1       0.857143
# 2       1.000000
# 3       0.750000
# 4       1.000000
# 5       0.750000
# 6       0.714286
# 7       0.714286
# 8       0.750000
# 9       1.000000
